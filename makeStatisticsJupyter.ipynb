# %% [markdown]
# ## Testing scenario #2

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("/home/barbora/PycharmProjects/DP-SecuritySDN/xTS_5_1_Specter.txt", delimiter=" ")
data.head(10)
data.groupby('State').sum()
# Out:
#                                                             Time  \
# State
# NEW_PACKET_IN  18:02:42.13661618:02:42.13726918:02:42.1377301...
# PASSED         18:02:42.18133818:02:42.18155718:02:42.1818061...
#
#                                                           Src_IP
# State
# NEW_PACKET_IN  10.0.0.6410.0.0.6010.0.0.6310.0.0.5710.0.0.591...
# PASSED         10.0.0.6410.0.0.6010.0.0.6310.0.0.5710.0.0.591...

# %%
county = data.groupby(['State']).count()
county
# Out:
#                Time  Src_IP
# State
# NEW_PACKET_IN  4875    4875
# PASSED         4872    4872

# %%
grouped_data = data.groupby(['State', 'Src_IP']).count()
grouped_data
# Out:
#                          Time
# State         Src_IP
# NEW_PACKET_IN 10.0.0.1     68
#               10.0.0.10    78
#               10.0.0.11    54
#               10.0.0.12    55
#               10.0.0.13    66
#               10.0.0.14    77
#               10.0.0.15    82
#               10.0.0.16    61
#               10.0.0.17    54
#               10.0.0.18    79
#               10.0.0.19    65
#               10.0.0.2     59
#               10.0.0.20    60
#               10.0.0.21    46
#               10.0.0.22    55
#               10.0.0.23    59
#               10.0.0.24    61
#               10.0.0.25    70
#               10.0.0.26    70
#               10.0.0.27    68
#               10.0.0.28    64
#               10.0.0.29    80
#               10.0.0.3     64
#               10.0.0.30    52
#               10.0.0.31    58
#               10.0.0.32    62
#               10.0.0.33    59
#               10.0.0.34    50
#               10.0.0.35    66
# ...

# %%
data['Time'] = data['Time'].apply(lambda x: x.split('.')[0])
data.groupby(['Time']).count().head(100)
# Out:
#           State  Src_IP
# Time
# 18:02:42    193     193
# 18:02:43    199     199
# 18:02:44    194     194
# 18:02:45    200     200
# 18:02:46    198     198
# 18:02:47    195     195
# 18:02:48    200     200
# 18:02:49    190     190
# 18:02:50    192     192
# 18:02:51    198     198
# 18:02:52    182     182
# 18:02:53    196     196
# 18:02:54    194     194
# 18:02:55    188     188
# 18:02:56    200     200
# 18:02:57    196     196
# 18:02:58    198     198
# 18:02:59    196     196
# 18:03:00    198     198
# 18:03:01    190     190
# 18:03:02    196     196
# 18:03:03    198     198
# 18:03:04    192     192
# 18:03:05    194     194
# 18:03:06    198     198
# 18:03:07    196     196
# 18:03:08    196     196
# 18:03:09    190     190
# 18:03:10    194     194
# 18:03:11    198     198
# 18:03:12    200     200
# 18:03:13    194     194
# 18:03:14    200     200
# 18:03:15    200     200
# 18:03:16    192     192
# 18:03:17    192     192
# 18:03:18    194     194
# ...

# %%
data['Cat'] = 'Good boys'
data.loc[data['Src_IP'].isin(['10.0.0.80', '10.0.0.81', '10.0.0.82', '10.0.0.83', '10.0.0.84', '10.0.0.85', '10.0.0.86', '10.0.0.87', '10.0.0.88', '10.0.0.89', '10.0.0.90', '10.0.0.91', '10.0.0.92', '10.0.0.93', '10.0.0.94', '10.0.0.95', '10.0.0.96', '10.0.0.97', '10.0.0.98', '10.0.0.99']), 'Cat'] = 'Bad boys'
data.head(100)
# Out:
#             State      Time     Src_IP        Cat
# 0   NEW_PACKET_IN  18:02:42  10.0.0.64  Good boys
# 1   NEW_PACKET_IN  18:02:42  10.0.0.60  Good boys
# 2   NEW_PACKET_IN  18:02:42  10.0.0.63  Good boys
# 3   NEW_PACKET_IN  18:02:42  10.0.0.57  Good boys
# 4   NEW_PACKET_IN  18:02:42  10.0.0.59  Good boys
# 5   NEW_PACKET_IN  18:02:42  10.0.0.71  Good boys
# 6   NEW_PACKET_IN  18:02:42  10.0.0.54  Good boys
# 7   NEW_PACKET_IN  18:02:42  10.0.0.51  Good boys
# 8   NEW_PACKET_IN  18:02:42  10.0.0.52  Good boys
# 9   NEW_PACKET_IN  18:02:42  10.0.0.74  Good boys
# 10  NEW_PACKET_IN  18:02:42  10.0.0.71  Good boys
# 11  NEW_PACKET_IN  18:02:42  10.0.0.70  Good boys
# 12  NEW_PACKET_IN  18:02:42  10.0.0.59  Good boys
# 13  NEW_PACKET_IN  18:02:42  10.0.0.73  Good boys
# 14  NEW_PACKET_IN  18:02:42  10.0.0.79  Good boys
# 15  NEW_PACKET_IN  18:02:42  10.0.0.57  Good boys
# 16  NEW_PACKET_IN  18:02:42  10.0.0.71  Good boys
# 17  NEW_PACKET_IN  18:02:42  10.0.0.62  Good boys
# ...

# %%
data.groupby(['Time', 'Cat', 'State']).count()
# Out:
#                                   Src_IP
# Time     Cat       State
# 18:02:42 Good boys NEW_PACKET_IN      97
#                    PASSED             96
# 18:02:43 Good boys NEW_PACKET_IN     100
#                    PASSED             99
# 18:02:44 Good boys NEW_PACKET_IN      97
#                    PASSED             97
# 18:02:45 Good boys NEW_PACKET_IN     100
#                    PASSED            100
# 18:02:46 Good boys NEW_PACKET_IN      99
#                    PASSED             99
# 18:02:47 Good boys NEW_PACKET_IN      98
#                    PASSED             97
# 18:02:48 Good boys NEW_PACKET_IN     100
#                    PASSED            100
# 18:02:49 Good boys NEW_PACKET_IN      95
#                    PASSED             95
# 18:02:50 Good boys NEW_PACKET_IN      96
#                    PASSED             96
# 18:02:51 Good boys NEW_PACKET_IN      99
#                    PASSED             99
# 18:02:52 Good boys NEW_PACKET_IN      91
# ...

# %%
# sel_data = data.loc[(data['State'] == 'PASSED') | (data['State'] == 'REJECTED')]
sel_data = data.loc[(data['State'].isin(['PASSED', 'REJECTED', 'REJECTED_blacklisted', 'REJECTED_POP', 'REJECTED_SERVICE_RATE_EXCEEDED']))]
sel_data.head()
# Out:
#      State      Time     Src_IP        Cat
# 50  PASSED  18:02:42  10.0.0.64  Good boys
# 51  PASSED  18:02:42  10.0.0.60  Good boys
# 52  PASSED  18:02:42  10.0.0.63  Good boys
# 53  PASSED  18:02:42  10.0.0.57  Good boys
# 54  PASSED  18:02:42  10.0.0.59  Good boys

# %%
sel_data.groupby(['State','Cat']).count()
# Out:
#                   Time  Src_IP
# State  Cat
# PASSED Good boys  4872    4872

# %% [markdown]
# ## Test case #1

# %%
import pandas as pd
import numpy as np

alldata = pd.read_csv("/home/barbora/PycharmProjects/DP-SecuritySDN/1_TS_Specter.txt", delimiter=" ")
alldata.shape
# Out:
# (9626, 3)

# %%
# data = alldata.loc[(alldata['Src_IP'] == '10.0.0.1') | (alldata['Src_IP'] == '10.0.0.2')]
data = alldata
data.head(20)
# Out:
#             State             Time     Src_IP
# 0   NEW_PACKET_IN  16:34:12.101182  10.0.0.32
# 1   NEW_PACKET_IN  16:34:12.106034  10.0.0.18
# 2   NEW_PACKET_IN  16:34:12.106518  10.0.0.39
# 3   NEW_PACKET_IN  16:34:12.106977   10.0.0.5
# 4   NEW_PACKET_IN  16:34:12.107457  10.0.0.12
# 5   NEW_PACKET_IN  16:34:12.108004  10.0.0.30
# 6   NEW_PACKET_IN  16:34:12.110781  10.0.0.45
# 7   NEW_PACKET_IN  16:34:12.111273  10.0.0.42
# 8   NEW_PACKET_IN  16:34:12.111731  10.0.0.30
# 9   NEW_PACKET_IN  16:34:12.112188  10.0.0.24
# 10  NEW_PACKET_IN  16:34:12.112621  10.0.0.25
# 11  NEW_PACKET_IN  16:34:12.113070   10.0.0.4
# 12  NEW_PACKET_IN  16:34:12.113543   10.0.0.9
# 13  NEW_PACKET_IN  16:34:12.113993  10.0.0.37
# 14  NEW_PACKET_IN  16:34:12.118202   10.0.0.3
# 15  NEW_PACKET_IN  16:34:12.118671  10.0.0.44
# 16  NEW_PACKET_IN  16:34:12.119122  10.0.0.25
# 17  NEW_PACKET_IN  16:34:12.119563  10.0.0.23
# 18  NEW_PACKET_IN  16:34:12.120013  10.0.0.25
# ...

# %%
data.shape
# Out:
# (9626, 3)

# %%
new_pcktin = data.loc[data['State'] == 'NEW_PACKET_IN']
new_pcktin.head()
# Out:
#            State             Time     Src_IP
# 0  NEW_PACKET_IN  16:34:12.101182  10.0.0.32
# 1  NEW_PACKET_IN  16:34:12.106034  10.0.0.18
# 2  NEW_PACKET_IN  16:34:12.106518  10.0.0.39
# 3  NEW_PACKET_IN  16:34:12.106977   10.0.0.5
# 4  NEW_PACKET_IN  16:34:12.107457  10.0.0.12

# %%
new_pcktin.shape
# Out:
# (4804, 3)

# %%
passed = data.loc[(data['State'] == 'PASSED') | (data['State'] == 'REJECTED') | (data['State'] == 'REJECTED_BLACKLISTED')]
passed.head()
# Out:
#      State             Time     Src_IP
# 43  PASSED  16:34:12.154463  10.0.0.32
# 44  PASSED  16:34:12.154692  10.0.0.18
# 45  PASSED  16:34:12.154947  10.0.0.39
# 46  PASSED  16:34:12.155148   10.0.0.5
# 47  PASSED  16:34:12.155358  10.0.0.12

# %%
passed.shape
# Out:
# (4803, 3)

# %%
import datetime, time
def time_difference(start, end):
#     start = '2016-08-15 ' + start
#     end = '2016-08-15 ' + end
    diff = datetime.datetime.strptime(end, "%H:%M:%S.%f") - datetime.datetime.strptime(start, "%H:%M:%S.%f")
    return float(diff.seconds * 1000000 + diff.microseconds)/1000000

new_passed = passed
merged = pd.DataFrame(columns=['Src_IP', 'Time', 'State'])
for i in new_pcktin.index:
    for j in new_passed.index:
        if new_pcktin['Src_IP'][i] == new_passed['Src_IP'][j]:
            passed_row = new_passed.loc[[j]]
            new_passed.drop(j, inplace=True)
            merged.loc[i] = [passed_row['Src_IP'][j], 
                             time_difference(new_pcktin['Time'][i], passed_row['Time'][j]),
                             passed_row['State'][j]]
            print 'Created row is', merged.loc[i]
            break
merged
# Out:
# Created row is Src_IP    10.0.0.32
# Time       0.053281
# State        PASSED
# Name: 0, dtype: object
# Created row is Src_IP    10.0.0.18
# Time       0.048658
# State        PASSED
# Name: 1, dtype: object
# Created row is Src_IP    10.0.0.39
# Time       0.048429
# State        PASSED
# Name: 2, dtype: object
# Created row is Src_IP    10.0.0.5
# Time      0.048171
# State       PASSED
# Name: 3, dtype: object
# Created row is Src_IP    10.0.0.12
# Time       0.047901
# State        PASSED
# Name: 4, dtype: object
# Created row is Src_IP    10.0.0.30
# Time       0.047534
# State        PASSED
# Name: 5, dtype: object
# Created row is Src_IP    10.0.0.45
# Time       0.044922
# State        PASSED
# Name: 6, dtype: object
# Created row is Src_IP    10.0.0.42
# Time       0.044621
# State        PASSED
# Name: 7, dtype: object
# Created row is Src_IP    10.0.0.30
# Time       0.044332
# State        PASSED
# Name: 8, dtype: object
# Created row is Src_IP    10.0.0.24
# ...

# %%
# merged[6] = 0

# import datetime, time
# def time_difference(start, end):
# #     start = '2016-08-15 ' + start
# #     end = '2016-08-15 ' + end
#     diff = datetime.datetime.strptime(end, "%H:%M:%S.%f") - datetime.datetime.strptime(start, "%H:%M:%S.%f")
#     return float(diff.seconds * 1000000 + diff.microseconds)/1000000

# merged[6] = merged.apply(lambda row: time_difference(row[1], row[4]), axis=1)
# merged.head()

# %%
PRIORITY = merged.sort_values(by=['Time'])
# PRIORITY.shape
xPRIORITY = PRIORITY.head(4793)
xPRIORITY.describe()
# Out:
#               Time
# count  4793.000000
# mean      0.052189
# std       0.158089
# min       0.000240
# 25%       0.010984
# 50%       0.019041
# 75%       0.033922
# max       0.992477

# %%
merged.describe()
# Out:
#               Time
# count  4803.000000
# mean      0.054189
# std       0.163884
# min       0.000240
# 25%       0.010992
# 50%       0.019100
# 75%       0.034117
# max       1.045564
